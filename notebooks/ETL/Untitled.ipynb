# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# agate                     1.9.1
# altair                    4.2.2
# annotated-types           0.7.0
# anyio                     4.5.2
# argon2-cffi               25.1.0
# argon2-cffi-bindings      21.2.0
# asttokens                 3.0.1
# async-lru                 2.0.4
# attrs                     25.3.0
# babel                     2.18.0
# backcall                  0.2.0
# backoff                   2.2.1
# backports.zoneinfo        0.2.1
# beautifulsoup4            4.14.3
# bleach                    6.1.0
# boto3                     1.37.32
# botocore                  1.37.38
# certifi                   2026.2.25
# cffi                      1.17.1
# charset-normalizer        3.4.4
# click                     8.1.8
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.1.1
# cryptography              46.0.5
# curl-cffi                 0.9.0
# ...

# %%
# !pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 317.8 MB 34 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 203 kB 3.3 MB/s eta 0:00:01
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.8-py2.py3-none-any.whl size=318352965 sha256=5410fb88cf58cb04ffd50a073c0edaa8800e14577420aa8513c3f226d3065b38
#   Stored in directory: /home/spark/.cache/pip/wheels/cb/82/23/0a9a39fcbd46101138a28b9958f50ab659eafedafc9e7b2392
# Successfully built pyspark
# ...
